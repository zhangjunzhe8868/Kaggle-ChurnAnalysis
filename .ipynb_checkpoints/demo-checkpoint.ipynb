# %% [markdown]
# # Customer Churn Analysis

# %% [markdown]
# ## Description
# Customer attrition, also known as customer churn, customer turnover, or customer defection, is the loss of clients or customers.
#
# Telephone service companies, Internet service providers, pay TV companies, insurance firms, and alarm monitoring services, often use customer attrition analysis and customer attrition rates as one of their key business metrics because the cost of retaining an existing customer is far less than acquiring a new one. Companies from these sectors often have customer service branches which attempt to win back defecting clients, because recovered long-term customers can be worth much more to a company than newly recruited clients.
#
# Companies usually make a distinction between voluntary churn and involuntary churn. Voluntary churn occurs due to a decision by the customer to switch to another company or service provider, involuntary churn occurs due to circumstances such as a customer's relocation to a long-term care facility, death, or the relocation to a distant location. In most applications, involuntary reasons for churn are excluded from the analytical models. Analysts tend to concentrate on voluntary churn, because it typically occurs due to factors of the company-customer relationship which companies control, such as how billing interactions are handled or how after-sales help is provided.
#
# Predictive analytics use churn prediction models that predict customer churn by assessing their propensity of risk to churn. Since these models generate a small prioritized list of potential defectors, they are effective at focusing customer retention marketing programs on the subset of the customer base who are most vulnerable to churn.

# %% [markdown]
# - Context
# Predict behavior to retain customers. You can analyze all relevant customer data and develop focused customer retention programs.
#
# - Content
# Each row represents a customer, each column contains customer’s attributes described on the column Metadata.
#
# - The data set includes information about:
#    1. Customers who left within the last month – the column is called Churn
#    2. Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
#    3. Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
#    4. Demographic info about customers – gender, age range, and if they have partners and dependents
#
# - Inspiration
# To explore this type of models and learn more about the subject.

# %% [markdown]
# ## Objective
#
# ### Your Tasks
#
# * Q1: Check the data to find if there's any problem. If you find any of the problem, explain how you would deal with that problem and perform any data clean-up process you see fit.
# * Q2: Perform an Exploratory Data Analysis to understand this dataset and describe all your insight
# * Q3: Now our customer management department would like to know if a given user would churn or not and ask you to build a predictive model to help them to recognize that.

# %% [markdown]
# **Metadata** <br />
# **customerID** - customer id <br />
# **gender** - client gender (male / female), bool <br />
# **SeniorCitizen** - is the client retired (1, 0), bool <br />
# **Partner** - is the client married (Yes, No), bool <br />
# **Dependents** - is the client's dependents (Yes, No), bool <br />
# **tenure** - how many months a person has been a client of the company <br />
# **Churn** - whether there was a churn (Yes or No), bool <br />
# **age** - year <br />
# **zipcode** - zipcode <br />
# **PhoneService** - is the telephone service connected (Yes, No), bool <br />
# **MultipleLines** - are multiple phone lines connected (Yes, No, No phone service), bool <br />
# **InternetService** - client's Internet service provider (DSL, Fiber optic, No), nominal <br />
# **OnlineSecurity** - is the online security service connected (Yes, No, No internet service), bool <br />
# **OnlineBackup** - is the online backup service activated (Yes, No, No internet service), bool <br />
# **DeviceProtection** - does the client have equipment insurance (Yes, No, No internet service), bool <br />
# **TechSupport** - is the technical support service connected (Yes, No, No internet service), bool <br />
# **StreamingTV** - is the streaming TV service connected (Yes, No, No internet service), bool <br />
# **StreamingMovies** - is the streaming cinema service activated (Yes, No, No internet service), bool <br />
# **Contract** - type of customer contract (Month-to-month, One year, Two year), nominal <br />
# **PaperlessBilling** - whether the client uses paperless billing (Yes, No), bool <br />
# **PaymentMethod** - payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic)), nominal <br />
# **MonthlyCharges** - current monthly payment <br />
# **TotalCharges** - the total amount that the client paid for the services for the entire time, str!!! <br />

# %% [markdown]
# ## answer Q1

# %% [markdown]
# ## answer Q2

# %% [markdown]
# ## answer Q3

# %% [markdown]
# ## 1. Load
# It is wired that the TotalCharges is object datatype, not float <br>
# We find there are some 11 rows that the TotalCharges is empty string <br>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import warnings
warnings.filterwarnings("ignore")

# %%
customer = pd.read_csv(r'data\raw\telcom_customer.csv')
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
#  5   tenure         7043 non-null   int64
#  6   Churn          7043 non-null   object
#  7   age            7043 non-null   int64
#  8   zipcode        7043 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 495.3+ KB

# %%
service = pd.read_csv(r'data\raw\telcom_service.csv')
service.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
#  10  Contract          7043 non-null   object
#  11  PaperlessBilling  7043 non-null   object
#  12  PaymentMethod     7043 non-null   object
#  13  MonthlyCharges    7043 non-null   float64
#  14  TotalCharges      7043 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 825.5+ KB

# %%
customer.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure Churn  age  \
# 0  7590-VHVEG  Female              0     Yes         No       1    No   56
# 1  5575-GNVDE    Male              0      No         No      34    No   49
# 2  3668-QPYBK    Male              0      No         No       2   Yes   19
# 3  7795-CFOCW    Male              0      No         No      45    No   56
# 4  9237-HQITU  Female              0      No         No       2   Yes   37
#
#    zipcode
# 0    90420
# 1    95057
# 2    69274
# 3    80998
# 4    47305

# %%
service.head()
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No
#
# ...

# %%
# data integration
df = pd.merge(customer, service, how='inner', on='customerID')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   Churn             7043 non-null   object
#  7   age               7043 non-null   int64
#  8   zipcode           7043 non-null   int64
#  9   PhoneService      7043 non-null   object
#  10  MultipleLines     7043 non-null   object
#  11  InternetService   7043 non-null   object
#  12  OnlineSecurity    7043 non-null   object
#  13  OnlineBackup      7043 non-null   object
#  14  DeviceProtection  7043 non-null   object
#  15  TechSupport       7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure Churn  age  \
# 0  7590-VHVEG  Female              0     Yes         No       1    No   56
# 1  5575-GNVDE    Male              0      No         No      34    No   49
# 2  3668-QPYBK    Male              0      No         No       2   Yes   19
# 3  7795-CFOCW    Male              0      No         No      45    No   56
# 4  9237-HQITU  Female              0      No         No       2   Yes   37
#
#    zipcode PhoneService  ... OnlineBackup DeviceProtection TechSupport  \
# 0    90420           No  ...          Yes               No          No
# 1    95057          Yes  ...           No              Yes          No
# 2    69274          Yes  ...          Yes               No          No
# 3    80998           No  ...           No              Yes         Yes
# 4    47305          Yes  ...           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# Data Overview
for count, col in enumerate(df.columns):
        print(df.loc[:,col].value_counts())
# Out:
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: customerID, Length: 7043, dtype: int64
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64
# No     5174
# Yes    1869
# Name: Churn, dtype: int64
# 33    158
# 19    154
# 38    149
# 41    145
# 24    145
#      ...
# 65     49
# 69     49
# 62     47
# 74     46
# 76     45
# Name: age, Length: 65, dtype: int64
# 30433    3
# 99264    3
# 18212    3
# 74564    3
# 55747    3
#         ..
# 17450    1
# 20652    1
# ...

# %%
# Check if there are empty string in TotalCharges
df.loc[df['TotalCharges']==" ",:]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure Churn  age  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0    No   32
# 753   3115-CZMZD    Male              0      No        Yes       0    No   50
# 936   5709-LVOEQ  Female              0     Yes        Yes       0    No   44
# 1082  4367-NUYAO    Male              0     Yes        Yes       0    No   36
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0    No   22
# 3331  7644-OMVMY    Male              0     Yes        Yes       0    No   55
# 3826  3213-VVOLG    Male              0     Yes        Yes       0    No   47
# 4380  2520-SGTTA  Female              0     Yes        Yes       0    No   32
# 5218  2923-ARZLG    Male              0     Yes        Yes       0    No   53
# 6670  4075-WKNIU  Female              0     Yes        Yes       0    No   37
# 6754  2775-SEFEE    Male              0      No        Yes       0    No   54
#
# ...

# %%
# Replacing spaces with null values in total charges column
df['TotalCharges'] = df["TotalCharges"].replace(" ",np.nan)
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# Churn                0
# age                  0
# zipcode              0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# dtype: int64

# %%
# Dropping null values from totalCharges column which contain 11 row missing data 
df_clean=df.copy()
df_clean = df_clean[df_clean["TotalCharges"].notnull()]
df_clean = df_clean.reset_index()[df_clean.columns]

# %%
# Convert to float type
df_clean["TotalCharges"] = df_clean["TotalCharges"].astype(float)

# %%
# Check the value distribution in totalCharges
sns.distplot(df_clean['TotalCharges'])
plt.show()

# %%
# Replace 'No internet service' to No for the following columns
# dimension reduction
replace_cols = [ 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                'TechSupport','StreamingTV', 'StreamingMovies']
for i in replace_cols : 
    df_clean[i]  = df_clean[i].replace({'No internet service' : 'No'})

# %%
df_clean['MultipleLines']  = df_clean['MultipleLines'].replace({'No phone service' : 'No'})

# %%
# Replace values
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_clean['Churn'] = le.fit_transform(df_clean['Churn'])

# %%
df_clean['SeniorCitizen'].replace({0:'No',1:'Yes'},inplace=True)

# %%
# Tenure to categorical column
def tenure_lab(telcom) :    
    if telcom["tenure"] <= 12 :
        return "Tenure_0-12"
    elif (telcom["tenure"] > 12) & (telcom["tenure"] <= 24):
        return "Tenure_12-24"
    elif (telcom["tenure"] > 24) & (telcom["tenure"] <= 48) :
        return "Tenure_24-48"
    elif (telcom["tenure"] > 48) & (telcom["tenure"] <= 60) :
        return "Tenure_48-60"
    elif telcom["tenure"] > 60 :
        return "Tenure_>60"
    
df_clean["tenure_group"] = df_clean.apply(lambda df_clean:tenure_lab(df_clean),axis = 1)

# %%
# Separating churn and non churn customers
churn     = df_clean[df_clean["Churn"] == 1]
not_churn = df_clean[df_clean["Churn"] == 0]

# %%
# Find catagorical columns
# Find numerical columns
cat_cols=['InternetService','Contract','PaymentMethod','tenure_group']
num_cols=['tenure', 'age', 'zipcode', 'MonthlyCharges', 'TotalCharges']

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# ## 2.1 Customer Atrrition in Data

# %%
df_clean['Churn'].value_counts(normalize=True)
# Out:
# 0    0.734215
# 1    0.265785
# Name: Churn, dtype: float64

# %% [markdown]
# ## 2.2 Varibles distribution in customer attrition

# %%
# function for pie plot for customer attrition types
# so it's easier to plot the pie chart for the column we want later
def pie(data,name):
    noC=data.loc[data['Churn']==0,:]
    C=data.loc[data['Churn']!=0,:]
    fig, axs = plt.subplots(1,2)
    axs[0].pie(noC.loc[:,name].value_counts(),labels=noC.loc[:,name].value_counts().index.tolist(), autopct='%1.1f%%')
    axs[0].set_title('non-Churn of '+name)
    axs[1].pie(C.loc[:,name].value_counts(),labels=C.loc[:,name].value_counts().index.tolist(), autopct='%1.1f%%')
    axs[1].set_title('Churn of '+name)
pie(df_clean,'gender')

# %%
pie(df_clean,'SeniorCitizen')

# %%
pie(df_clean,'Dependents')

# %%
pie(df_clean,'Partner')

# %%
pie(df_clean,'PhoneService')

# %%
pie(df_clean,'MultipleLines')

# %%
pie(df_clean,'OnlineSecurity')

# %%
pie(df_clean,'OnlineBackup')

# %%
pie(df_clean,'DeviceProtection')

# %%
pie(df_clean,'TechSupport')

# %%
pie(df_clean,'StreamingTV')

# %%
pie(df_clean,'StreamingMovies')

# %%
pie(df_clean,'PaperlessBilling')

# %%
# plot function for the histogram
# so it's easier to plot the histogram for the column we want
def bar(data,name):
    noC=data.loc[data['Churn']==0,:]
    C=data.loc[data['Churn']!=0,:]
    fig, axs = plt.subplots(1,2)
    axs[0].bar(noC.loc[:,name].value_counts().index, noC.loc[:,name].value_counts().values)
    axs[0].set_title('non-Churn of '+name)
    axs[0].set_xticklabels(noC.loc[:,name].value_counts().index,rotation=45,ha='right')
    axs[1].bar(C.loc[:,name].value_counts().index, C.loc[:,name].value_counts().values)
    axs[1].set_title('Churn of '+name)
    axs[1].set_xticklabels(C.loc[:,name].value_counts().index,rotation=45,ha='right')
bar(df_clean,'InternetService')

# %%
bar(df_clean,'Contract')

# %%
bar(df_clean,'PaymentMethod')

# %%
bar(df_clean,'tenure_group')

# %%
plt.scatter(df_clean.loc[df_clean['Churn']==0,'MonthlyCharges'],
            df_clean.loc[df_clean['Churn']==0,'TotalCharges'],
            c = 'red',label='non-Churn')
plt.scatter(df_clean.loc[df_clean['Churn']!=0,'MonthlyCharges'],
            df_clean.loc[df_clean['Churn']!=0,'TotalCharges'],
            c = 'blue',label='Churn')
plt.xlabel('MonthlyCharges')
plt.ylabel('TotalCharges')
plt.legend()

# %%
plt.scatter(df_clean.loc[df_clean['Churn']==0,'tenure'],
            df_clean.loc[df_clean['Churn']==0,'TotalCharges'],
            c = 'red',label='non-Churn')
plt.scatter(df_clean.loc[df_clean['Churn']!=0,'tenure'],
            df_clean.loc[df_clean['Churn']!=0,'TotalCharges'],
            c = 'blue',label='Churn')
plt.xlabel('tenure')
plt.ylabel('TotalCharges')
plt.legend()

# %%
plt.scatter(df_clean.loc[df_clean['Churn']==0,'tenure'],
            df_clean.loc[df_clean['Churn']==0,'MonthlyCharges'],
            c = 'red',label='non-Churn')
plt.scatter(df_clean.loc[df_clean['Churn']!=0,'tenure'],
            df_clean.loc[df_clean['Churn']!=0,'MonthlyCharges'],
            c = 'blue',label='Churn')
plt.xlabel('tenure')
plt.ylabel('MonthlyCharges')
plt.legend()

# %% [markdown]
# ## 2.3 Customer attrition in tenure groups

# %%
X_axis = df_clean['tenure_group'].value_counts()
X_axis.index.tolist()
# Out:
# ['Tenure_0-12', 'Tenure_24-48', 'Tenure_>60', 'Tenure_12-24', 'Tenure_48-60']

# %%
non_churn = df_clean.loc[df_clean['Churn']==0,'tenure_group'].value_counts()
churn = df_clean.loc[df_clean['Churn']!=0,'tenure_group'].value_counts()
X=np.arange(len(X_axis.index.tolist()))  
plt.bar(X - 0.2, non_churn, 0.4, label = 'non-Churn')
plt.bar(X + 0.2, churn, 0.4, label = 'Churn')
 
plt.xticks(X, X_axis.index.tolist(), rotation=45, ha='right')
plt.xlabel("tenure group")
plt.ylabel("count")
plt.legend()

# %% [markdown]
# ## 2.4 Monthly Charges and Total Charges by Tenure and Churn Groups

# %%
X_axis = df_clean['tenure_group'].value_counts()
X_axis.index.tolist()
# Out:
# ['Tenure_0-12', 'Tenure_24-48', 'Tenure_>60', 'Tenure_12-24', 'Tenure_48-60']

# %%
plt.scatter(df_clean.loc[df_clean['tenure_group']=='Tenure_0-12','MonthlyCharges'],
            df_clean.loc[df_clean['tenure_group']=='Tenure_0-12','TotalCharges'],
            c = 'red',label='Tenure_0-12')
plt.scatter(df_clean.loc[df_clean['tenure_group']=='Tenure_24-48','MonthlyCharges'],
            df_clean.loc[df_clean['tenure_group']=='Tenure_24-48','TotalCharges'],
            c = 'blue',label='Tenure_24-48')
plt.scatter(df_clean.loc[df_clean['tenure_group']=='Tenure_60<','MonthlyCharges'],
            df_clean.loc[df_clean['tenure_group']=='Tenure_60<','TotalCharges'],
            c = 'green',label='Tenure_60<')
plt.scatter(df_clean.loc[df_clean['tenure_group']=='Tenure_12-24','MonthlyCharges'],
            df_clean.loc[df_clean['tenure_group']=='Tenure_12-24','TotalCharges'],
            c = 'yellow',label='Tenure_12-24')
plt.scatter(df_clean.loc[df_clean['tenure_group']=='Tenure_48-60','MonthlyCharges'],
            df_clean.loc[df_clean['tenure_group']=='Tenure_48-60','TotalCharges'],
            c = 'black',label='Tenure_48-60')
plt.xlabel("MonthlyCharges")
plt.ylabel("TotalCharges")
plt.legend()

# %%
plt.scatter(df_clean.loc[df_clean['Churn']==0,'MonthlyCharges'],
            df_clean.loc[df_clean['Churn']==0,'TotalCharges'],
            c = 'red',label='non-Churn')
plt.scatter(df_clean.loc[df_clean['Churn']!=0,'MonthlyCharges'],
            df_clean.loc[df_clean['Churn']!=0,'TotalCharges'],
            c = 'blue',label='Churn')
plt.xlabel("MonthlyCharges")
plt.ylabel("TotalCharges")
plt.legend()

# %% [markdown]
# ### 2.5 Average Charges by tenure groups
# * have an idea about what is the average charges in each tenure groups

# %%
avg_tgc = df_clean.groupby(["tenure_group","Churn"])[["MonthlyCharges","TotalCharges"]].mean().reset_index()
avg_tgc
# Out:
#    tenure_group  Churn  MonthlyCharges  TotalCharges
# 0   Tenure_0-12      0       46.766169    265.768146
# 1   Tenure_0-12      1       66.493973    288.532064
# 2  Tenure_12-24      0       54.449589   1018.113493
# 3  Tenure_12-24      1       78.509014   1394.778401
# 4  Tenure_24-48      0       61.174783   2233.539007
# 5  Tenure_24-48      1       84.500000   3003.136462
# 6  Tenure_48-60      0       67.579143   3693.971770
# 7  Tenure_48-60      1       88.182500   4762.820000
# 8    Tenure_>60      0       74.440563   5086.077549
# 9    Tenure_>60      1       97.317742   6517.167204

# %%
X_axis = df_clean['tenure_group'].value_counts()
X_axis.index.tolist()
# Out:
# ['Tenure_0-12', 'Tenure_24-48', 'Tenure_>60', 'Tenure_12-24', 'Tenure_48-60']

# %%
non_churn = avg_tgc.loc[avg_tgc['Churn']==0,'MonthlyCharges']
churn = avg_tgc.loc[avg_tgc['Churn']!=0,'MonthlyCharges']
X=np.arange(len(X_axis.index.tolist()))  
plt.bar(X - 0.2, non_churn, 0.4, label = 'non-Churn')
plt.bar(X + 0.2, churn, 0.4, label = 'Churn')
  
plt.xlabel("tenure group")
plt.ylabel("mean monthly charges")
plt.xticks(X, X_axis.index.tolist(), rotation=45, ha='right')
plt.legend()

# %%
X_axis = df_clean['tenure_group'].value_counts()
X_axis.index.tolist()
# Out:
# ['Tenure_0-12', 'Tenure_24-48', 'Tenure_>60', 'Tenure_12-24', 'Tenure_48-60']

# %%
non_churn = avg_tgc.loc[avg_tgc['Churn']==0,'TotalCharges']
churn = avg_tgc.loc[avg_tgc['Churn']!=0,'TotalCharges']
X=np.arange(len(X_axis.index.tolist()))  
plt.bar(X - 0.2, non_churn, 0.4, label = 'non-Churn')
plt.bar(X + 0.2, churn, 0.4, label = 'Churn')
  
plt.xlabel("tenure group")
plt.ylabel("mean total charges")
plt.xticks(X, X_axis.index.tolist(), rotation=45, ha='right')
plt.legend()

# %% [markdown]
# ## 2.6 Monthly charges,total charges and tenure in customer attrition
# * Take a look at the monthly charges and total charges in each tenure group, and how that affect customer attrtion

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# Data for three-dimensional scattered points
xdata=df_clean.loc[df_clean['Churn']==0,'MonthlyCharges']
ydata=df_clean.loc[df_clean['Churn']==0,'TotalCharges']
zdata=df_clean.loc[df_clean['Churn']==0,'tenure']

xdata1=df_clean.loc[df_clean['Churn']==1,'MonthlyCharges']
ydata1=df_clean.loc[df_clean['Churn']==1,'TotalCharges']
zdata1=df_clean.loc[df_clean['Churn']==1,'tenure']

ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens')
ax.scatter3D(xdata1, ydata1, zdata1, c=zdata1, cmap='Oranges')

# %%
from sklearn.preprocessing import LabelEncoder # transform non-numerical labels to numerical labels
from sklearn.preprocessing import StandardScaler #standardize by subtract by mean, divided by SD

# %%
#Target columns
target_col = ["Churn"]
#categorical columns
cat_cols=['InternetService','Contract','PaymentMethod','tenure_group']
#numerical columns
num_cols=['tenure', 'age', 'zipcode', 'MonthlyCharges', 'TotalCharges']
#Binary columns with 2 values
bin_cols=['gender','SeniorCitizen','Partner','Dependents','PhoneService',
         'MultipleLines','OnlineSecurity','OnlineBackup',
         'DeviceProtection','TechSupport','StreamingTV','StreamingMovies',
         'PaperlessBilling']

# %%
#Label encoding Binary columns
le = LabelEncoder()
for col in bin_cols :
    df_clean[col] = le.fit_transform(df_clean[col])

# %%
#Duplicating columns for multi value columns
df_clean = pd.get_dummies(data = df_clean,columns = cat_cols)

# %%
#Scaling Numerical columns
std = StandardScaler()
df_clean[num_cols] = std.fit_transform(df_clean[num_cols])

# %% [markdown]
# ## 2.7 Variable Summary
#
# Take a look at all of the variables and how they distributed in this dataset

# %%
df_clean.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents        tenure  \
# count  7032.000000    7032.000000  7032.000000  7032.000000  7.032000e+03
# mean      0.504693       0.162400     0.482509     0.298493 -1.214741e-16
# std       0.500014       0.368844     0.499729     0.457629  1.000071e+00
# min       0.000000       0.000000     0.000000     0.000000 -1.280248e+00
# 25%       0.000000       0.000000     0.000000     0.000000 -9.542963e-01
# 50%       1.000000       0.000000     0.000000     0.000000 -1.394171e-01
# 75%       1.000000       0.000000     1.000000     1.000000  9.199259e-01
# max       1.000000       1.000000     1.000000     1.000000  1.612573e+00
#
#              Churn           age       zipcode  PhoneService  MultipleLines  \
# count  7032.000000  7.032000e+03  7.032000e+03   7032.000000    7032.000000
# mean      0.265785 -2.636030e-17 -1.016678e-16      0.903299       0.421928
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 35 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customerID                               7032 non-null   object
#  1   gender                                   7032 non-null   int32
#  2   SeniorCitizen                            7032 non-null   int32
#  3   Partner                                  7032 non-null   int32
#  4   Dependents                               7032 non-null   int32
#  5   tenure                                   7032 non-null   float64
#  6   Churn                                    7032 non-null   int32
#  7   age                                      7032 non-null   float64
#  8   zipcode                                  7032 non-null   float64
#  9   PhoneService                             7032 non-null   int32
# ...

# %% [markdown]
# ## 2.8 Correlation Matrix
#
# From the correlation matrix we can have an idea about how they related to each other pairwisely

# %%
#correlation
plt.figure(figsize = (5,5))
sns.heatmap(df_clean[num_cols].corr(), cmap = "RdYlGn", annot = True, annot_kws={"fontsize":8}, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# How Can I Deal With This Problem? <br />
# There are multiple ways to deal with this problem. The easiest way is to delete or eliminate one of the perfectly correlated features. Another way is to use a dimension reduction algorithm such as Principle Component Analysis (PCA).

# %% [markdown]
# - Pearson Correlation
#
# Pearson correlation measures the linear relationship between the variables. It assumes that the variables are normally distributed.
# The Pearson correlation is calculated by dividing the covariance of the two variables by the product of their standard deviations. Covariance measures how the two variables move with each other over time. As we divide the covariance by the standard deviations, we make the Pearson correlation unit-less and hence it is always between the values -1 and 1.
# The biggest limitation of Pearson correlation is that it assumes that the variables have linear relationship between them. Most of the variables do not have linear relationships. As an instance, the financial assets have a non linear relationship between them.
# When the value of Pearson correlation is 0, it means that there is no linear relationship between the two variables. However, there could be a non-linear relationship between the variables. Hence the value 0 does not imply that the two variables are completely independent of each other.
# The variance of the variables is expected to be finite. This is not the case most of the times, as an instance when the distribution is Student-t.
# The Pearson correlation is changed once we transform the data. Often, in the data science projects, we calculate the log of a variable to transform it into a linear variable. The side effect of it is that the Pearson correlation will also change.

# %% [markdown]
# Other types
# - Spearman Ranking Correlation (time series)
# - Kendall Correlation Measure (a nonparametric measure that does not require any assumptions regarding the joint probability distributions of variables)

# %% [markdown]
# ## 2.9 Visualising data with principal components

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
X = df_clean.drop(['customerID','Churn'],axis=1)
pca_df = pca.fit_transform(X)
labels = df_clean['Churn']

x=pca_df[:,0]
y=pca_df[:,1]

# %%
pc=pd.DataFrame({"PC1":x,"PC2":y,"CLUSTER":labels})
sns.scatterplot(x=pc["PC1"],y=pc["PC2"],hue=pc["CLUSTER"],palette="Set2")
# Out:
# <AxesSubplot:xlabel='PC1', ylabel='PC2'>

# %% [markdown]
# ## 2.10 Binary variables distribution in customer attrition(Radar Chart)

# %%
radar_bin=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'InternetService_DSL', 'InternetService_Fiber optic',
       'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
       'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
       'PaymentMethod_Credit card (automatic)',
       'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
       'tenure_group_Tenure_0-12', 'tenure_group_Tenure_12-24',
       'tenure_group_Tenure_24-48', 'tenure_group_Tenure_48-60',
       'tenure_group_Tenure_>60']

# %%
Churn_count1=[]
Churn_count0=[]
noChurn_count1=[]
noChurn_count0=[]
for col in radar_bin:
    Churn1=len(df_clean.loc[(df_clean['Churn']==1)&(df_clean[col]==1),:])
    Churn0=len(df_clean.loc[(df_clean['Churn']==1)&(df_clean[col]==0),:])
    noChurn1=len(df_clean.loc[(df_clean['Churn']==0)&(df_clean[col]==1),:])
    noChurn0=len(df_clean.loc[(df_clean['Churn']==0)&(df_clean[col]==0),:])
    Churn_count1.append(Churn1)
    Churn_count0.append(Churn0)
    noChurn_count1.append(noChurn1)
    noChurn_count0.append(noChurn0)

# %%
def radar(data1,data0,label,n):
    from math import pi
 
    # number of variable
    categories=label
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(111, polar=True)

    # Draw one axe per variable + add labels
    plt.xticks(angles[:-1], categories, color='grey', size=6)
    # Draw ylabels
    ax.set_rlabel_position(5)
    ax.set_xticklabels(categories, rotation=45)
    plt.yticks([int(n/2),n], [str(int(n/2)),str(n)], color="black", size=8)
    plt.ylim(0,n)

    # We are going to plot the first line of the data frame.
    # But we need to repeat the first value to close the circular graph
    # Plot data
    # Fill area
    values=data1
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label="Churn")
    ax.fill(angles, values, 'b', alpha=0.1)

    values=data0
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label="non-Churn")
    ax.fill(angles, values, 'r', alpha=0.1)

    # Add legend
    plt.legend(loc='center left')
radar(Churn_count1,Churn_count0,radar_bin,1800)

# %%
radar(noChurn_count1,noChurn_count0,radar_bin,5000)

# %% [markdown]
# # 4. Model Building

# %% [markdown]
# ## 4.1. Baseline Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import f1_score,precision_score,recall_score

# %%
inlist=['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'age', 'zipcode', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'MonthlyCharges',
       'TotalCharges', 'InternetService_DSL', 'InternetService_Fiber optic',
       'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
       'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
       'PaymentMethod_Credit card (automatic)',
       'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
       'tenure_group_Tenure_0-12', 'tenure_group_Tenure_12-24',
       'tenure_group_Tenure_24-48', 'tenure_group_Tenure_48-60',
       'tenure_group_Tenure_>60']

# %%
#splitting train and test data 
Y = df_clean['Churn'] # give the target variable another name
X = df_clean.drop(['Churn', 'customerID'], axis= 1) # drop the target variable and id to make the data ready for training
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=1234) # split the training data with the test proportion set to 0.2

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state = 11,n_jobs=-1) 
os_sm_X, os_sm_Y = sm.fit_resample(x_train,y_train)
os_sm_X = pd.DataFrame(data = os_sm_X,columns=inlist)
os_sm_Y = pd.DataFrame(data = os_sm_Y,columns=['Churn'])

# %%
from imblearn.under_sampling import TomekLinks

tl = TomekLinks(n_jobs=-1) 
us_tl_X, us_tl_Y = tl.fit_resample(x_train,y_train)
us_tl_X = pd.DataFrame(data = us_tl_X,columns=inlist)
us_tl_Y = pd.DataFrame(data = us_tl_Y,columns=['Churn'])

# %%
data = [[x_train, y_train],
        [os_sm_X, os_sm_Y],
        [us_tl_X, us_tl_Y]]

# %%
def evl(model,data):
    for features, labels in data:
        model.fit(features, labels)
        predict_test = model.predict(x_test) 
        cm=confusion_matrix(y_test,predict_test)
        print('auc:%.3f' %roc_auc_score(y_test, predict_test))
        print("AccuracyScore:%.3f" %accuracy_score(y_test,predict_test))
        print("Precision:%.3f" %precision_score(y_test,predict_test,average='micro'))
        print("False Alarm Rate:%.3f" %(cm[1][0]/(cm[1][0]+cm[1][1])))

# %%
logit  = LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
          penalty='l2', random_state=1234, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
evl(logit,data)
# Out:
# auc:0.711
# AccuracyScore:0.804
# Precision:0.804
# False Alarm Rate:0.484
# auc:0.752
# AccuracyScore:0.784
# Precision:0.784
# False Alarm Rate:0.316
# auc:0.739
# AccuracyScore:0.805
# Precision:0.805
# False Alarm Rate:0.399

# %%
logit_f  = LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
          penalty='l2', random_state=1234, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False)
logit_f.fit(us_tl_X, us_tl_Y)
# Out:
# LogisticRegression(multi_class='ovr', n_jobs=-1, random_state=1234,
#                    solver='liblinear')

# %%
mydict_lg={}
for i,key in enumerate(x_train.columns[:-1]):
    mydict_lg[key]=mydict_lg.get(key,0)+abs(logit_f.coef_.ravel()[i])
pd_lg=pd.DataFrame.from_dict(mydict_lg, orient='index')
pd_lg.columns=['feature importance']
pd_lg.nlargest(5,columns='feature importance')
# Out:
#                              feature importance
# tenure                                 1.545808
# InternetService_No                     1.002462
# Contract_Two year                      0.851990
# tenure_group_Tenure_12-24              0.682165
# InternetService_Fiber optic            0.548789

# %% [markdown]
# Tip:
# F1 score (also F-score or F-measure) is a measure of a test's accuracy. It considers both the precision p and the recall r of the test to compute the score: p is the number of correct positive results divided by the number of all positive results returned by the classifier, and r is the number of correct positive results divided by the number of all relevant samples (all samples that should have been identified as positive). The F1 score is the harmonic mean of the precision and recall, where an F1 score reaches its best value at 1 (perfect precision and recall) and worst at 0.

# %% [markdown]
# ## 4.2. Feature Selection

# %%
# Feature ranking with recursive feature elimination
from sklearn.feature_selection import RFE

logit = LogisticRegression()

rfe = RFE(logit,n_features_to_select=10,step=1)
rfe = rfe.fit(x_train, y_train.values.ravel())

print('select features: ',rfe.support_)
print('feature ranking: ',rfe.ranking_)

#identified columns Recursive Feature Elimination
idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                       "columns" : [i for i in x_train.columns],
                       "ranking" : rfe.ranking_,
                      })
cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()
# Out:
# select features:  [False False False False  True False False  True False  True False False
#  False False False False False  True False  True  True  True False  True
#  False False False False False False False  True  True]
# feature ranking:  [22  4 24 13  1 18 23  1  8  1 11 14  5  9  6  2 15  1 21  1  1  1 16  1
#  20 17  3 19 10  7 12  1  1]

# %%
cat=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'InternetService_DSL', 'InternetService_Fiber optic',
       'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
       'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
       'PaymentMethod_Credit card (automatic)',
       'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
       'tenure_group_Tenure_0-12', 'tenure_group_Tenure_12-24',
       'tenure_group_Tenure_24-48', 'tenure_group_Tenure_48-60',
       'tenure_group_Tenure_>60']
con=['tenure', 'age', 'zipcode', 'MonthlyCharges', 'TotalCharges']

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_classif

selector = SelectKBest(chi2, k=10)
selector.fit(x_train[cat], y_train)
print(selector.get_support())
print(x_train[cat].columns[selector.get_support()])

selector = SelectKBest(f_classif, k=2)
selector.fit(x_train[con], y_train)
print(selector.get_support())
print(x_train[con].columns[selector.get_support()])
# Out:
# [False  True False False False False  True False False False False False
#  False False  True  True  True  True  True False False  True False  True
#  False False False  True]
# Index(['SeniorCitizen', 'OnlineSecurity', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Electronic check',
#        'tenure_group_Tenure_0-12', 'tenure_group_Tenure_>60'],
#       dtype='object')
# [ True False False False  True]
# Index(['tenure', 'TotalCharges'], dtype='object')
